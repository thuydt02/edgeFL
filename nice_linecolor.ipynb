# %%
import matplotlib.pyplot as plt
import numpy as np

BG_WHITE = "#fbf9f4"
BLUE = "#2a475e"
GREY70 = "#b3b3b3"
GREY_LIGHT = "#f2efe8"
COLORS = ["#FF5A5F", "#FFB400", "#007A87"]

plt.plot(range(100), range(100), color = COLORS[0])
plt.plot(range(100), np.asarray(range(100)) * 0.5, color = COLORS[1])
plt.plot(range(100), np.asarray(range(100)) * 0.25, color = COLORS[2])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path_file = "./output/cifar100/z_ass/"

# %%
partition_file = "partition_noniid-#label2_nclient100.npy"
z_rnd_file = "1z_rnd_num_client100.part12"
z_metis_vw_file = "g_vw_q_d_euclidean_partition_noniid-#label2_nclient100.npy.part.15"
z_metis_nw_file = "g_nw_q_d_euclidean_partition_noniid-#label2_nclient100.npy.part.15"

# %%
p = []
n_parties = 100
with open(path_file + partition_file, 'rb') as f:
    for i in range(n_parties):
        p.append(np.load(f))
        
f = open(path_file + z_rnd_file, 'r')
z_rnd = np.asarray([int(line.strip()) for line in f.readlines()])
f.close()

f = open(path_file + z_metis_vw_file, 'r')
z_metis_vw = np.asarray([int(line.strip()) for line in f.readlines()])
f.close()

f = open(path_file + z_metis_nw_file, 'r')
z_metis_nw = np.asarray([int(line.strip()) for line in f.readlines()])
f.close()

# %%
print(p)
# Out:
# [array([ 9470, 27272, 30172, 43691, 45171,  1979, 32714, 48715, 16637,
#        16352, 26042, 26604, 39278, 30631, 17727, 33950, 45682, 35849,
#        16353,  4142, 21752, 36562, 26006, 11507,  4767, 43210,  2537,
#        36693, 10958, 25342, 42441, 12946, 13528, 20402, 37402, 48921,
#        32233, 44180, 35665, 25902, 33563,  5077, 40475, 23856,  8065,
#          176, 22768, 33690, 41754, 11121, 36481, 17450, 34952, 15482,
#        14461,  1238, 33773, 18064, 24134, 34921,  8180, 29275, 38908,
#        42117, 31697, 20941,   822, 45717, 28648,  8045, 15274,  7136,
#        34665, 48100, 18564, 36391, 28092, 11065, 48823, 31148, 31600,
#        25705, 46274, 23582, 33983, 33748, 41819, 16540, 35223,  5950,
#        23780, 40446, 38278, 21290, 19002, 37334,  6247, 43219,  6438,
#        21870, 11402, 34254,  7498, 46220,   459, 41242, 12208, 25768,
#        31492, 16356, 28722,   587, 14869,   658, 45370, 42780, 37763,
# ...

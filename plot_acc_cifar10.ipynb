# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path_file = "./output/cifar10/acc/"

# %%
#L10E2
files = [
#10    
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E2_G5000_avg5z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#20
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E2_G5000_avg10z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
    
#30
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E2_G5000_avg10z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ]
]

clusters = ['10', '20', '30']
algs = ['z_rnd', 'z_metis']


n_clusters = len(clusters)
n_algs = len(algs)
dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

features = ['test_acc']

fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,12))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Test Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,6))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Test Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

# %%
#L10E5

files = [
#10    
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_1z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#15
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_1z_rnd_num_client300.part15_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.15.weight.pth.acc.csv",
         ],
#20
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_1z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
    
#25
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_1z_rnd_num_client300.part25_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.25.weight.pth.acc.csv",
         ],
#30
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_1z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L10_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ]
]

dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

features = ['test_acc']

fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,15))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Test Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,7))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Train Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

# %%
#L20E2

files = [
#10    
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_1z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#15
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_1z_rnd_num_client300.part15_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.15.weight.pth.acc.csv",
         ],
#20
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_1z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
    
#25
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_1z_rnd_num_client300.part25_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.25.weight.pth.acc.csv",
         ],
#30
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_1z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E2_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ]
]

dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

features = ['test_acc']

fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,15))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Test Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,7))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Test Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

# %%
#L20E5

files = [
#10    
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_avg5z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#15
  #      ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_1z_rnd_num_client300.part15_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
  #       "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.15.weight.pth.acc.csv",
  #       ],
#20
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_avg10z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
    
#25
  #      ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_1z_rnd_num_client300.part25_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
  #       "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.25.weight.pth.acc.csv",
  #       ],
#30
        ["eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_avg10z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
         "eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G5000_g_nw_d_euclidean_CNN2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ]
]

dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

features = ['test_acc']

fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,12))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Test Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,6))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Test Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

# %%
import numpy as np

num_clients = 300
src_fname = "./output/mnist/z_ass/partition_noniid90_label3_nclient300.npy"
partition_list = []
with open(src_fname, 'rb') as f:
    for cl in range(num_clients):
        partition_list.append(np.load(f))
print(partition_list[:3])
# Out:
# [array([    1,    21,    34,    37,    51,    56,    63,    68,    69,
#           75,    81,    88,    95,   108,   114,   118,   119,   121,
#          156,   169,   192,   206,   209,   210,   216,   229,   232,
#          234,   246,   249,   260,   283,   293,   296,   303,   320,
#          326,   359,   399,   427,   429,   435,   440,   451,   453,
#          458,   462,   464,   473,   489,   519,   524,   526,   527,
#          542,   577,   582,   596,   603,   612, 32778, 16396, 32781,
#        32785, 16402, 49171, 32789, 32793, 16412, 16415, 32800, 49185,
#        16423, 32810, 16428, 16429, 49197, 49199, 49200, 16439, 49208,
#        49214, 32834, 49218, 49220, 49221, 49224, 32843, 16460, 32846,
#        49229, 32858, 16474, 49243, 49244, 32867, 16484, 32869, 16485,
#        49263, 32880, 16498, 49268, 16501, 49278, 49280, 49281, 32899,
#        16516, 16518, 16519, 16520, 32905, 16523, 49304, 49306, 32925,
# ...

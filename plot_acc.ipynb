# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
files = [
#10    
        ["eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part10.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#20
        ["eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part20.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
#30
        ["eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part30.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ],
    
#40
        ["eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part40.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.40.weight.pth.acc.csv",
         ],
#41
#        ["eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part41.weight.pth.acc.csv",
#         "eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.41.weight.pth.acc.csv",
#         ],
#50
        ["eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part50.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.50.weight.pth.acc.csv",
         ],
        
    
]

clusters = ['10', '20', '30', '40', '50']
algs = ['z_rnd', 'z_metis']


n_clusters = len(clusters)
n_algs = len(algs)
dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

features = ['train_acc']
fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,15))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Train Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,7))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Train Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

# %%
#L10E10

files = [
#10    
        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part10.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#20
        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part20.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
#30
        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part30.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ],
    
#40
        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part40.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.40.weight.pth.acc.csv",
         ],
#41
#        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part41.weight.pth.acc.csv",
#         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.41.weight.pth.acc.csv",
#         ],
#50
        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part50.weight.pth.acc.csv",
         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.50.weight.pth.acc.csv",
         ],
        
    
]

clusters = ['10', '20', '30', '40', '50']
algs = ['z_rnd', 'z_metis']


n_clusters = len(clusters)
n_algs = len(algs)
dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,15))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Train Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,7))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Train Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

# %%
#L50E2

files = [
#10    
        ["eFL_MLP2_B10_L50_E2_G5000_1z_rnd_num_client300.part10.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#20
        ["eFL_MLP2_B10_L50_E2_G5000_1z_rnd_num_client300.part20.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
#30
        ["eFL_MLP2_B10_L50_E2_G5000_1z_rnd_num_client300.part30.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ],
    
#40
        ["eFL_MLP2_B10_L50_E2_G5000_1z_rnd_num_client300.part40.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.40.weight.pth.acc.csv",
         ],
#41
#        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part41.weight.pth.acc.csv",
#         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.41.weight.pth.acc.csv",
#         ],
#50
        ["eFL_MLP2_B10_L50_E2_G5000_1z_rnd_num_client300.part50.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.50.weight.pth.acc.csv",
         ],
        
    
]

clusters = ['10', '20', '30', '40', '50']
algs = ['z_rnd', 'z_metis']


n_clusters = len(clusters)
n_algs = len(algs)
dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

features = ['train_acc']
fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,15))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Train Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,7))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Train Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

# %%
#L50E10

files = [
#10    
        ["eFL_MLP2_B10_L50_E10_G5000_1z_rnd_num_client300.part10.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",
         ],
#20
        ["eFL_MLP2_B10_L50_E10_G5000_1z_rnd_num_client300.part20.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
         ],
#30
        ["eFL_MLP2_B10_L50_E10_G5000_1z_rnd_num_client300.part30.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
         ],
    
#40
        ["eFL_MLP2_B10_L50_E10_G5000_1z_rnd_num_client300.part40.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.40.weight.pth.acc.csv",
         ],
#41
#        ["eFL_MLP2_B10_L10_E10_G5000_1z_rnd_num_client300.part41.weight.pth.acc.csv",
#         "eFL_MLP2_B10_L10_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.41.weight.pth.acc.csv",
#         ],
#50
        ["eFL_MLP2_B10_L50_E10_G5000_1z_rnd_num_client300.part50.weight.pth.acc.csv",
         "eFL_MLP2_B10_L50_E10_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.50.weight.pth.acc.csv",
         ],
        
    
]

clusters = ['10', '20', '30', '40', '50']
algs = ['z_rnd', 'z_metis']


n_clusters = len(clusters)
n_algs = len(algs)
dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    for j in range(n_algs):
        dfs[i].append(pd.read_csv(path_file + files[i][j]))
        

features = ['train_acc']
fig, ax = plt.subplots(int (n_clusters/2) + 1, 2, figsize=(15,15))

for i in range(n_clusters):
    for j in range(n_algs):
        ax[int(i/2), i % 2].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[int(i/2), i % 2].set_title("cluster_" + str(clusters[i]))
    ax[int(i/2), i % 2].set_ylabel("Train Accuracy (%)")
    ax[int(i/2), i % 2].set_xlabel("Training Time")
    ax[int(i/2), i % 2].legend(loc='best')


plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,7))


for j in range(n_algs):
    for i in range(n_clusters):
        ax[j].plot(dfs[i][j].global_round, dfs[i][j][features[0]], label = files[i][j])
    
    ax[j].set_title("alg_" + str(algs[j]))
    ax[j].set_ylabel("Train Accuracy")
    ax[j].set_xlabel("Training Time")
    ax[j].legend(loc='best')

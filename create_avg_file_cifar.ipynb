# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path_file = "./output/cifar10/acc/iid"

# %%
#L10E2

L, E = 20, 5
LE = "L" + str(L) + "_E" + str(E)
path_file = path_file + "/L" + str(L) + "E" + str(E) + "/"
files = [
    #L20E5 noniid, all done
#10    
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#       "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg5z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv"

#        ],
#20        
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_9z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_10z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg10z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv"

#        ],
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_7z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_8z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg10z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv"

#        ]

#]


#L10E2 noniid all done
#10    
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_2z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_3z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_4z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_5z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#       "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg5z_rnd_num_client300.part10_partition_noniid90_nclient300.npy.weight.pth.acc.csv"

#        ],
#20        
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_2z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_3z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_4z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_5z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg10z_rnd_num_client300.part20_partition_noniid90_nclient300.npy.weight.pth.acc.csv"

#        ],
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_2z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_3z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_4z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_5z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg10z_rnd_num_client300.part30_partition_noniid90_nclient300.npy.weight.pth.acc.csv"

#        ]

#]
#L10E2 iid done
#10    
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",

#       "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg5z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv"

#        ],
#20        
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_1z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
        #not existed "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
        
        #not existed "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg10z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv"

#        ],
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G2000_1z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
        #not existed "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
        #not existed "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G5000_avg10z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv"

#        ]
#]


#L20E5 iid
#10    
        [
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_1z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        
        #not existed "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_11z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_12z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_13z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv",
        

        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_avg10z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv"

       ],
#20        
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_1z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
        # not existed "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
        # not existed "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_avg10z_rnd_num_client300.part20_partition_iid_nclient300.npy.weight.pth.acc.csv"

#        ],
#        [
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_1z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_2z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_3z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_4z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_5z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_6z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_7z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_8z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_9z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_10z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv",
        
#        "eFL_CNN2_dr10lr0.15_dc0.99_B20_" + LE + "_G3000_avg10z_rnd_num_client300.part30_partition_iid_nclient300.npy.weight.pth.acc.csv"

#        ]
]

# %%
clusters = [10]
n_clusters = len(clusters)
step = L * E
dfs = [[] for _ in range(n_clusters)]

for i in range(n_clusters):
    ni_files = len(files[i])
    for j in range(ni_files - 1):
        df = pd.read_csv(path_file + files[i][j])
        max_global_round = max(df.global_round)
        #print("j, max_global_ground ", j, ", ", max_global_round)
        if max_global_round < 3000: #3000 for L20E5 iid
            train_loss = df[df.global_round == max_global_round].train_loss.values[0]
            train_acc = df[df.global_round == max_global_round].train_acc.values[0]
            test_loss = df[df.global_round == max_global_round].test_loss.values[0]
            test_acc = df[df.global_round == max_global_round].test_acc.values[0]
            
            for e in range(max_global_round + step, 3000 + step, step): #3000 for L20E5
                df = df.append(pd.DataFrame({'global_round': [e], 'train_loss' : [train_loss], 'train_acc': [train_acc], 'test_loss':[test_loss], 'test_acc':[test_acc]}),
                                      ignore_index = True)
                #print(e, ", ", train_loss, ",", train_acc, ",", test_loss, ",", test_acc )
        
        count_nan_in_df = df.isnull().sum().sum()
        #print(df.shape)
        print(files[i][j])
        print("#NAN: ", count_nan_in_df)
        if count_nan_in_df == 0:
            dfs[i].append(df)
    print("cluster ", clusters[i], "len dfs: ", len(dfs[i]))
# Out:
# eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G3000_1z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv
# #NAN:  0
# eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G3000_2z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv
# #NAN:  56
# eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G3000_3z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv
# #NAN:  0
# eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G3000_4z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv
# #NAN:  56
# eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G3000_5z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv
# #NAN:  58
# eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G3000_6z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv
# #NAN:  0
# eFL_CNN2_dr10lr0.15_dc0.99_B20_L20_E5_G3000_7z_rnd_num_client300.part10_partition_iid_nclient300.npy.weight.pth.acc.csv
# #NAN:  0
# ...

# %%
dfs[0][1].shape
# Out:
# (30, 5)

# %%
for i in range(n_clusters):
    ni_dfs = len(dfs[i])
    ni_files = len(files[i])
    
    train_loss_list = []
    train_acc_list = []
    test_loss_list = []
    test_acc_list = []
    for j in range(ni_dfs):
        if train_loss_list == []:
            train_loss_list = np.asarray(dfs[i][j].train_loss)
            train_acc_list = np.asarray(dfs[i][j].train_acc)
            test_loss_list = np.asarray(dfs[i][j].test_loss)
            test_acc_list = np.asarray(dfs[i][j].test_acc)
        else:
            train_loss_list = np.add(train_loss_list, np.asarray(dfs[i][j].train_loss))
            train_acc_list = np.add(train_acc_list, np.asarray(dfs[i][j].train_acc))
            test_loss_list = np.add(test_loss_list, np.asarray(dfs[i][j].test_loss))
            test_acc_list = np.add(test_acc_list, np.asarray(dfs[i][j].test_acc))
            
    train_loss_list = np.asarray(train_loss_list) /(ni_dfs)
    train_acc_list = np.asarray(train_acc_list) /(ni_dfs)
    test_loss_list = np.asarray(test_loss_list) /(ni_dfs)
    test_acc_list = np.asarray(test_acc_list) /(ni_dfs)
    
    df = pd.DataFrame(columns = ['global_round', 'train_loss', 'train_acc', 'test_loss', 'test_acc'])
    df.global_round = dfs[i][0].global_round
    df.train_loss = train_loss_list
    df.train_acc = train_acc_list
    df.test_loss = test_loss_list
    df.test_acc = test_acc_list
    
    print(df)
    df.to_csv(path_file + files[i][ni_files - 1])
# Out:
#     global_round  train_loss  train_acc  test_loss   test_acc
# 0            100    1.976586  28.713393   1.967277  29.497143
# 1            200    2.281304  37.163988   2.317267  36.975714
# 2            300    2.162117  40.077976   2.229628  39.215714
# 3            400    2.159965  41.917560   2.252951  40.388571
# 4            500    2.149091  43.004167   2.263511  40.711429
# 5            600    2.194150  43.758036   2.329274  41.002857
# 6            700    2.249041  44.354167   2.404884  40.997143
# 7            800    2.401347  45.085714   2.586337  41.341429
# 8            900    2.540427  45.457440   2.743435  41.388571
# 9           1000    2.745678  45.748214   2.980047  41.458571
# 10          1100    2.893787  46.009821   3.144619  41.498571
# 11          1200    3.068052  46.191667   3.342553  41.445714
# 12          1300    3.201288  46.318452   3.495769  41.380000
# 13          1400    3.294561  46.438095   3.600503  41.421429
# ...

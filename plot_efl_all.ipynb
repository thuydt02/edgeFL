# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_file = "./output/mnist/acc/"
#files = ["eFL_MLP2_B10_L40_E2_G500000_1z_rnd_num_client1000.part23.weight.pth.acc.csv",
#        "1eFL_MLP2_B10_L40_E2_G500000_g_d_euclidean_partition_noniid-labeldir0.175_nclient1000.npy.part.25.weight.pth.acc.csv"]

files = [
    #mnist_100
        "eFL_MLP2_B10_L10_E2_G1000_1z_rnd_num_client300.part37.weight.pth.acc.csv",
        "eFL_MLP2_B10_L40_E2_G1000_1z_rnd_num_client300.part37.weight.pth.acc.csv"
        #"eFL_MLP2_B10_L10_E2_G1000_1z_rnd_num_client300.part42.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E5_G1000_1z_rnd_num_client300.part42.weight.pth.acc.csv"

        #mnist_path_file + "eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part40.weight.pth.acc.csv",
        
        #"eFL_MLP2_B10_L10_E5_G1000_1z_rnd_num_client300.part42.weight.pth.acc.csv",
    #femnist
        #"eFL_MLP2_B50_L10_E2_G2000_1z_rnd_num_client1000.part50.weight.pth.acc.csv"
        #"eFL_MLP2_B10_L10_E2_G500000_1z_rnd_num_client1000.part25.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G500000_g_nw_q_d_euclidean_partition_noniid-labeldir0.175_nclient1000.npy.part.25.weight.pth.acc.csv"
    #-------------
        
        #"eFL_MLP2_B10_L10_E2_G500000_1z_rnd_num_client1000.part25.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G500000_g_nw_q_d_euclidean_partition_noniid-labeldir0.175_nclient1000.npy.part.25.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G500000_g_nw_d_euclidean_partition_noniid-labeldir0.175_nclient1000.npy.part.35.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G500000_1z_rnd_num_client1000.part35.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G500000_g_d_euclidean_partition_noniid-labeldir0.175_nclient1000.npy.part.35.weight.pth.acc.csv"
        #"eFL_sCNN_B10_L10_E2_G500000_g_nw_d_euclidean_partition_noniid-#label2_nclient100.npy.part.10.weight.pth.acc.csv"
        #"eFL_sCNN_B10_L10_E2_G500000_1z_rnd_num_client100.part10.weight.pth.acc.csv",
        #"eFL_sCNN_B10_L10_E2_G500000_g_nw_q_d_euclidean_partition_noniid-#label2_nclient100.npy.part.15_q_lognorm_part100.npy.weight.pth.acc.csv",
        #"eFL_sCNN_B10_L10_E2_G500000_1z_rnd_num_client100.part14.weight.pth.acc.csv"
        #"eFL_CNN2_B10_L10_E2_G500000_g_nw_q_d_euclidean_partition_noniid-#label2_nclient100.npy.part.15.weight.pth.acc.csv"
        #"eFL_CNN2_B10_L10_E2_G500000_1z_rnd_num_client100.part14_q_lognorm_part100.npy.weight.pth.acc.csv"
        #"eFL_CNN3_B10_L10_E2_G500000_g_nw_q_d_euclidean_partition_noniid-#label2_nclient100.npy.part.15.weight.pth.acc.csv"
        #"eFL_CNN3_B10_L10_E2_G500000_1z_rnd_num_client100.part14_q_lognorm_part100.npy.weight.pth.acc.csv"
        #"eFL_CNN2_B10_L10_E4_G2100_1z_rnd_num_client100.part12_q_lognorm_part100.npy.weight.pth.acc.csv",
        #"eFL_CNN2_B10_L10_E4_G2100_g_vw_q_d_euclidean_partition_noniid-#label2_nclient100.npy.part.15.weight.pth.acc.csv"
        #"eFL_CNN2_B10_L10_E4_G5000_1z_rnd_num_client100.part12_q_lognorm_part100.npy.weight.pth.acc.csv"
        #"eFL_CNN2_B10_L10_E4_G5000_g_vw_q_no_d.csv.part.12.weight.pth.acc.csv"
        #"eFL_CNN2_B10_L10_E4_G5000_g_vw_q_d_euclidean_partition_noniid-#label2_nclient100.npy.part.15.weight.pth.acc.csv"
        
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client100.part7.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client100.part7_q_lognorm_part100.npy.weight.pth.acc.csv"
        
        #"eFL_MLP2_B10_L10_E2_G5000_2z_rnd_num_client100.part7.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_2z_rnd_num_client100.part7_q_lognorm_part100.npy.weight.pth.acc.csv",
        
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid82_nclient100.npy.part.7.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_g_qw_d_euclidean_MLP2_G10_partition_noniid82_nclient100.npy.part.7.weight.pth.acc.csv",

    
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client100.part10.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid82_nclient100.npy.part.10.weight.pth.acc.csv"

        #-------------        
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part10.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.10.weight.pth.acc.csv",

        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part20.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.20.weight.pth.acc.csv",
    
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part30.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv",
    
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part40.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.40.weight.pth.acc.csv",
    
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part50.weight.pth.acc.csv"
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.50.weight.pth.acc.csv"
        
        #"eFL_qMLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part30_q_lognorm_part300.npy.weight.pth.acc.csv",
        #"eFL_qMLP2_B10_L10_E2_G5000_g_qw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv"
        
        #"eFL_qMLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part40_q_lognorm_part300.npy.weight.pth.acc.csv",
        # "eFL_qMLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.40.weight.pth.acc.csv",
        # "eFL_qMLP2_B10_L10_E2_G5000_g_qw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.40.weight.pth.acc.csv"
        #"eFL_MLP2_B10_L10_E2_G5000_1z_rnd_num_client300.part30.weight.pth.acc.csv",
        #"eFL_MLP2_B10_L10_E2_G5000_g_nw_d_euclidean_MLP2_G10_partition_noniid90_nclient300.npy.part.30.weight.pth.acc.csv"
         
         

    
]
         
n_files = len(files)
dfs = []
for i in range(n_files):
    dfs.append(pd.read_csv(path_file + files[i]))
        

features = [['train_loss', 'train_acc'],[ 'test_loss', 'test_acc']]
fig, ax = plt.subplots(2,2, figsize=(15,10))
    
for i in range(2):
    for j in range(2):
        for fi in range(n_files):
            ax[i,j].plot(dfs[fi].global_round, dfs[fi][features[i][j]], label = files[fi])
        ax[i,j].set_ylabel(features[i][j])
        ax[i,j].set_xlabel("Global time")
        ax[i,j].legend(loc='best')


plt.show()
